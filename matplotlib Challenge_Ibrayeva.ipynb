# %% [markdown]
# >## Assignment 5: MatplotLib Challenge
#
# >*Sofiya Ibrayeva*
#
# >**01.30.2024**

# %%
#Importing required libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %% [markdown]
# **Grouped bar chart**
# - A grouped bar chart is a powerful tool for effectively visualizing and comparing statistical data. I think as a data analyst, it would be a helpful tool to visualize and compare sales data across different products, regions, and time periods in a clear and concise manner. The grouping and stacking of bars make it easy to identify patterns and variations in sales performance. Also if we want to visualize the sales data of 3 products for the past 5 years, the comparison between 3 products would be very easily achieved, which in my opinion is one of the great benefits of this figure. What I would like to learn about this figure is how I can visualize it better. For example, how can i highlight only a certain bar and gray out the rest of them in a figure. Or how can I add numeric inf to certain columns ot how can i add the trend line.

# %%
ls
# Out:
# Ibrayeva_PandasChallenge.csv
# Ibrayeva_PandasChallenge.ipynb
# PandasInClass_Ibrayeva.ipynb
# Salary Data.csv
# Spotify_Montero_data.json
# amazon_2024_valentines_best_sellers.csv
# cces_example_data copy.csv
# cces_example_data.csv
# chessbuds_messages.json
# commute.csv
# ibrayeva_SystemsCheck.ipynb
# in class_4.ipynb
# in class_week3.ipynb
# in class_week4.ipynb
# matplotlib Challenge_Ibrayeva.ipynb
# matplotlib_inclass.ipynb
# seaborn_practice.ipynb
# subset_cces_example_data.csv
# tidyChallenge_Ibrayeva.ipynb

# %%
#Importing the data as the dataframe using pandas
data=pd.read_csv('cces_example_data copy.csv')

# %%
#Exploring the data
data.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %%
data.columns
# Out:
# Index(['pew_religimp', 'pew_churatd', 'sex', 'educ', 'nonwhite', 'age',
#        'faminc_new', 'pid3', 'ideo5', 'QueerPhobia', 'ImmiPhobia',
#        'InterGBiasParty', 'InterGBiasCand', 'InterGBiasSup', 'LibMediaUse',
#        'ConMediaUse', 'Real_Threat', 'Symb_Threat', 'Evaluation', 'teamweight',
#        'caseid'],
#       dtype='object')

# %%
data.describe()
# Out:
#        pew_religimp  pew_churatd         sex        educ    nonwhite  \
# count    659.000000   659.000000  659.000000  659.000000  659.000000
# mean       2.342944     4.294385    1.559939    3.813354    1.254932
# std        1.192998     1.725409    0.496771    1.471121    0.436154
# min        1.000000     1.000000    1.000000    1.000000    1.000000
# 25%        1.000000     3.000000    1.000000    2.000000    1.000000
# 50%        2.000000     5.000000    2.000000    4.000000    1.000000
# 75%        4.000000     6.000000    2.000000    5.000000    2.000000
# max        4.000000     7.000000    2.000000    6.000000    2.000000
#
#               age  faminc_new        pid3       ideo5  QueerPhobia  ...  \
# count  659.000000  659.000000  659.000000  659.000000   659.000000  ...
# mean    52.180577   15.908953    1.977238    3.083460     2.600910  ...
# std     16.842264   27.724506    0.860002    1.282575     1.163468  ...
# ...

# %%
#Creating an empty figure with two axes
fig1, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

#Setting titles for axises
ax1.set_title('Age Histogram')
ax2.set_title('Political Identity')

plt.show()

# %%
#Creating a figure with two axes
fig2, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

#Setting titles for axises
ax1.set_title('Age Histogram')
ax2.set_title('Political Identity')
#creating histograms for the age and political identity distibution (im not sure whether the pid3 stands for the political identity but thats what google told me )
ax1.hist(x= data['age'], color='black')
ax2.hist(x = data['pid3'], color='purple')
plt.show()

# %%
#Ceating the bar chart for the evaluation column
# I chose to use the groupby method based on the ideo5 column
evaluation_freq = data.groupby('Evaluation')['ideo5'].count()
evaluation_freq.index
                               
fig3, ax3 = plt.subplots(figsize = (10, 5))
ax3.bar(x= evaluation_freq.index, height = evaluation_freq, color='skyblue')
ax3.set_title('Evaluation of Ideological Position (ideo5)')
plt.show()

# %%
#creating a scatter plot 
fig4,ax4 = plt.subplots()
ax4.scatter(x=data['ConMediaUse'], y=data['ImmiPhobia'], color='green')
#adding labels and a title 
ax4.set_xlabel('ConMediaUse')
ax4.set_ylabel('ImmiPhobia')
ax4.set_title('Scatter Plot of ConMediaUse vs. ImmiPhobia')
plt.show()
